# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Avacado.csv')
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# 3  2015.0  Albany
# 4  2015.0  Albany

# %%
df.shape
# Out:
# (16468, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# There is a huge data in a sequence which is missing

# %%
df.isnull()
# Out:
#        Unnamed: 0   Date  AveragePrice  Total Volume   4046   4225   4770  \
# 0           False  False         False         False  False  False  False
# 1           False  False         False         False  False  False  False
# 2           False  False         False         False  False  False  False
# 3           False  False         False         False  False  False  False
# 4           False  False         False         False  False  False  False
# ...           ...    ...           ...           ...    ...    ...    ...
# 16463        True   True          True          True   True   True   True
# 16464        True   True          True          True   True   True   True
# 16465        True   True          True          True   True   True   True
# 16466        True   True          True          True   True   True   True
# 16467        True   True          True          True   True   True   True
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags   type   year  region
# 0           False       False       False        False  False  False   False
# 1           False       False       False        False  False  False   False
# 2           False       False       False        False  False  False   False
# 3           False       False       False        False  False  False   False
# 4           False       False       False        False  False  False   False
# ...           ...         ...         ...          ...    ...    ...     ...
# 16463        True        True        True         True   True   True    True
# 16464        True        True        True         True   True   True    True
# 16465        True        True        True         True   True   True    True
# 16466        True        True        True         True   True   True    True
# 16467        True        True        True         True   True   True    True
#
# [16468 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %% [markdown]
# The above stats shows that maximum data is missing from the dateset and it is in a sequence hence it will effect the performance of our model if we fill these nan values.
# Hence we will be removing all the missing values

# %%
df[df.isnull()]
# Out:
#        Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 0             NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 1             NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 2             NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 3             NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 4             NaN  NaN           NaN           NaN   NaN   NaN   NaN
# ...           ...  ...           ...           ...   ...   ...   ...
# 16463         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16464         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16465         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16466         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16467         NaN  NaN           NaN           NaN   NaN   NaN   NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags type  year region
# 0             NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 1             NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 2             NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 3             NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 4             NaN         NaN         NaN          NaN  NaN   NaN    NaN
# ...           ...         ...         ...          ...  ...   ...    ...
# 16463         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16464         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16465         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16466         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16467         NaN         NaN         NaN          NaN  NaN   NaN    NaN
#
# [16468 rows x 14 columns]

# %%
df.shape
# Out:
# (16468, 14)

# %%
df.dropna(how='any',inplace=True)

# %%
df
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0            0.0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1            1.0  20-12-2015          1.35      54876.98    674.28   44638.81
# 2            2.0  13-12-2015          0.93     118220.22    794.70  109149.67
# 3            3.0  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4            4.0  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512        10.0  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513        11.0  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514        12.0  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515        13.0  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516        14.0  18-09-2016          1.43     182978.30  43116.41   54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0        48.16     8696.87     8603.62       93.25         0.00  conventional
# 1        58.33     9505.56     9408.07       97.49         0.00  conventional
# 2       130.50     8145.35     8042.21      103.14         0.00  conventional
# 3        72.58     5811.16     5677.40      133.76         0.00  conventional
# 4        75.78     6183.95     5986.26      197.69         0.00  conventional
# ...        ...         ...         ...         ...          ...           ...
# 1512  17531.78    59418.46    48823.53    10354.65       240.28  conventional
# 1513  19419.57    63300.70    54704.14     8596.56         0.00  conventional
# 1514  16736.92    62415.77    53332.61     8258.16       825.00  conventional
# 1515  17495.42    63931.73    55653.47     8278.26         0.00  conventional
# 1516  16563.91    69104.56    57456.21    11648.35         0.00  conventional
#
#         year     region
# 0     2015.0     Albany
# 1     2015.0     Albany
# 2     2015.0     Albany
# 3     2015.0     Albany
# 4     2015.0     Albany
# ...      ...        ...
# 1512  2016.0  Charlotte
# 1513  2016.0  Charlotte
# 1514  2016.0  Charlotte
# 1515  2016.0  Charlotte
# 1516  2016.0  Charlotte
#
# [1517 rows x 14 columns]

# %%
df.shape
# Out:
# (1517, 14)

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# There are no missing values in this dataset

# %%
df.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# std    1.377812e+05  7.579765e+05  6.474765e+05  1.182157e+05    7455.712144
# min    0.000000e+00  3.311770e+03  3.311770e+03  0.000000e+00       0.000000
# 25%    9.112500e+02  3.620689e+04  2.972722e+04  5.407400e+02       0.000000
# 50%    7.688170e+03  7.397906e+04  6.237569e+04  5.044350e+03       0.000000
# 75%    2.916730e+04  1.576097e+05  1.461994e+05  2.926767e+04     401.480000
# max    1.381516e+06  6.736304e+06  5.893642e+06  1.121076e+06  108072.790000
#
#               year
# count  1517.000000
# mean   2015.162821
# std       0.369324
# min    2015.000000
# 25%    2015.000000
# 50%    2015.000000
# 75%    2015.000000
# max    2016.000000

# %%
#Dropping columns which re not required
df.drop(df.columns[0],axis=1,inplace=True)
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region
# 0  Albany
# 1  Albany
# 2  Albany
# 3  Albany
# 4  Albany

# %%
#Extract the Month from DOB into separate column
df['Month'] = pd.DatetimeIndex(df['Date']).month
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region  Month
# 0  Albany     12
# 1  Albany     12
# 2  Albany     12
# 3  Albany      6
# 4  Albany     11

# %%
#Extract the Date from DOB into separate column
df['Date'] = pd.DatetimeIndex(df['Date']).day
df.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0    27          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1    20          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2    13          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3    12          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4    29          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type    year  region  Month
# 0     8603.62       93.25          0.0  conventional  2015.0  Albany     12
# 1     9408.07       97.49          0.0  conventional  2015.0  Albany     12
# 2     8042.21      103.14          0.0  conventional  2015.0  Albany     12
# 3     5677.40      133.76          0.0  conventional  2015.0  Albany      6
# 4     5986.26      197.69          0.0  conventional  2015.0  Albany     11

# %%
df['type'].unique()
# Out:
# array(['conventional'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
column = ['type','region']
le = LabelEncoder()
for i in column:
    df[i] = le.fit_transform(df[i].astype(str))

print(df.dtypes)
# Out:
# Date              int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year            float64
# region            int32
# Month             int64
# dtype: object

# %%
#Data Visuallisation

# %%
sns.barplot(x='year',y='AveragePrice',data=df)

# %%
# the above barplot shows that price increases in 2016 as compared to 2015

# %%
region = df.groupby(['region'])['Total Volume'].sum().reset_index()
top_region = region.nlargest(10,'Total Volume')
plt.figure(figsize=(15,8))
ax=sns.barplot(x='region',y='Total Volume',data=top_region,color='b')

# %%
df.hist(figsize=(20,20),grid=True,layout=(4,4),bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002886D1CB640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886D213DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886D249310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886D272AC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002886D2A9280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886DF2F940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886DF2FA30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886DF66280>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002886DFB8160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886DFEF880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886E0190A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886E04D7C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002886E078F40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886E0AB700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886E0D7DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002886E0FE730>]],
#       dtype=object)

# %% [markdown]
# Findings from above histogram
#
# Average Price is normally distributed over the histogram 2.Rest of the data are not much varying in terms of numbers ,so they are left skewed data

# %%
df.type  =df.type.astype(float)

# %%
#plotting the boxplot of each column to check the outliers
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(15,10))
# Out:
# Date                AxesSubplot(0.125,0.71587;0.133621x0.16413)
# AveragePrice     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Total Volume      AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4046             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 4225             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# 4770               AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Total Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Small Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Large Bags      AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# type               AxesSubplot(0.125,0.321957;0.133621x0.16413)
# year            AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# region           AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# Month           AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# dtype: object

# %%
#checking the co-relation of all column to each other
df_cor = df.corr()
plt.figure(figsize=(30,25))
sns.heatmap(df_cor,annot=True)
plt.plot()
# Out:
# []

# %%
#assign the value of x and y for training and testing phase
x = df.drop(columns=['AveragePrice','Date'])
y = df[["AveragePrice"]]
print(x.shape)
print(y.shape)
# Out:
# (1517, 12)
# (1517, 1)

# %%
#Standardize the value of x so that mean will 0 and SD will become 1 , and make the data as normal distributed
sc = StandardScaler()
sc.fit_transform(x)
x = pd.DataFrame(x,columns=x.columns)

# %% [markdown]
# # Modeling

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LogisticRegression,Lasso,LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),LinearRegression(),GradientBoostingRegressor()]
max_r2_score = 0
for r_state in range(40,90):
    train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = r_state,test_size = 0.33)
    for i in model:
        i.fit(train_x,train_y)
        pre = i.predict(test_x)
        r2_sc = r2_score(test_y,pre)
        print("R2 score correspond to random state " ,r_state ,"is", r2_sc)
        if r2_sc> max_r2_score:
            max_r2_score=r2_sc
            final_state = r_state
            final_model = i
        
print("max R2 score correspond to random state " ,final_state , "is" , max_r2_score ,"and model is",final_model)
# Out:
# R2 score correspond to random state  40 is 0.5918190565237651
# R2 score correspond to random state  40 is 0.7212305865668154
# R2 score correspond to random state  40 is 0.5995716235530797
# R2 score correspond to random state  40 is 0.09687651952550791
# R2 score correspond to random state  40 is 0.7320004242269738
# R2 score correspond to random state  41 is 0.6826526514818357
# R2 score correspond to random state  41 is 0.7227453956696386
# R2 score correspond to random state  41 is 0.5978123107891424
# R2 score correspond to random state  41 is 0.15011629678756622
# R2 score correspond to random state  41 is 0.748804318033004
# R2 score correspond to random state  42 is 0.6303435209446266
# R2 score correspond to random state  42 is 0.6938824375584891
# R2 score correspond to random state  42 is 0.6169203587021668
# R2 score correspond to random state  42 is 0.17771882612399847
# R2 score correspond to random state  42 is 0.7394975176073262
# R2 score correspond to random state  43 is 0.6459923786921536
# R2 score correspond to random state  43 is 0.7594205428027004
# R2 score correspond to random state  43 is 0.5750702677183213
# R2 score correspond to random state  43 is 0.19024240844166418
# R2 score correspond to random state  43 is 0.7604106759316295
# R2 score correspond to random state  44 is 0.5190838325845726
# R2 score correspond to random state  44 is 0.6576758179209434
# R2 score correspond to random state  44 is 0.48939288071021003
# R2 score correspond to random state  44 is 0.10735892176424844
# R2 score correspond to random state  44 is 0.676844304108403
# R2 score correspond to random state  45 is 0.6152151677479571
# R2 score correspond to random state  45 is 0.6144226595738589
# R2 score correspond to random state  45 is 0.5510518407851182
# R2 score correspond to random state  45 is 0.11923943868531872
# R2 score correspond to random state  45 is 0.6933939500351767
# R2 score correspond to random state  46 is 0.6255106532789488
# R2 score correspond to random state  46 is 0.6935253042398841
# R2 score correspond to random state  46 is 0.5961492387584653
# R2 score correspond to random state  46 is 0.21321295186050437
# R2 score correspond to random state  46 is 0.7204550904809952
# R2 score correspond to random state  47 is 0.681953677897577
# R2 score correspond to random state  47 is 0.7517062415396552
# R2 score correspond to random state  47 is 0.6162357113530617
# R2 score correspond to random state  47 is 0.17497976251728276
# R2 score correspond to random state  47 is 0.7619139401973231
# R2 score correspond to random state  48 is 0.5665519694854212
# R2 score correspond to random state  48 is 0.723843992773087
# R2 score correspond to random state  48 is 0.590974343826242
# R2 score correspond to random state  48 is 0.12324794173624731
# R2 score correspond to random state  48 is 0.7374982310623847
# R2 score correspond to random state  49 is 0.5999572976969322
# R2 score correspond to random state  49 is 0.740337070461043
# R2 score correspond to random state  49 is 0.584712281163744
# R2 score correspond to random state  49 is 0.14314794439974943
# R2 score correspond to random state  49 is 0.7062759511258803
# R2 score correspond to random state  50 is 0.6273747823857854
# R2 score correspond to random state  50 is 0.6650585206842957
# R2 score correspond to random state  50 is 0.5837108858356533
# R2 score correspond to random state  50 is 0.14958159117132652
# R2 score correspond to random state  50 is 0.701271789353513
# R2 score correspond to random state  51 is 0.6577676591441406
# R2 score correspond to random state  51 is 0.7262282212477907
# R2 score correspond to random state  51 is 0.6024844707525016
# R2 score correspond to random state  51 is 0.18464741684995234
# R2 score correspond to random state  51 is 0.7286393304984147
# R2 score correspond to random state  52 is 0.6584657136280541
# R2 score correspond to random state  52 is 0.7404287635936344
# R2 score correspond to random state  52 is 0.5957312300144506
# R2 score correspond to random state  52 is 0.2066367825243114
# R2 score correspond to random state  52 is 0.7391841134706255
# R2 score correspond to random state  53 is 0.6668927759531216
# R2 score correspond to random state  53 is 0.7036026963482661
# R2 score correspond to random state  53 is 0.6100089514908782
# R2 score correspond to random state  53 is 0.15547713844943734
# R2 score correspond to random state  53 is 0.7442485858118468
# R2 score correspond to random state  54 is 0.544202840645205
# R2 score correspond to random state  54 is 0.7389558915915531
# R2 score correspond to random state  54 is 0.5925768876076709
# R2 score correspond to random state  54 is 0.18685585250792824
# R2 score correspond to random state  54 is 0.7286307495532983
# R2 score correspond to random state  55 is 0.6160611529436063
# R2 score correspond to random state  55 is 0.7517019092926542
# R2 score correspond to random state  55 is 0.6102957706871521
# R2 score correspond to random state  55 is 0.21448399228899007
# R2 score correspond to random state  55 is 0.7425357100620367
# R2 score correspond to random state  56 is 0.4746795378332439
# R2 score correspond to random state  56 is 0.6753082099018688
# R2 score correspond to random state  56 is 0.5533168098887109
# R2 score correspond to random state  56 is 0.10270258509503549
# R2 score correspond to random state  56 is 0.6968075017348744
# R2 score correspond to random state  57 is 0.6539827703206168
# R2 score correspond to random state  57 is 0.7228626568758558
# R2 score correspond to random state  57 is 0.6263128489001739
# R2 score correspond to random state  57 is 0.17510882772266423
# R2 score correspond to random state  57 is 0.7516353643337883
# R2 score correspond to random state  58 is 0.5577726959768787
# R2 score correspond to random state  58 is 0.7047118633899978
# R2 score correspond to random state  58 is 0.5862442765694116
# R2 score correspond to random state  58 is 0.1452962037135731
# R2 score correspond to random state  58 is 0.721348749215721
# R2 score correspond to random state  59 is 0.6731604016012623
# R2 score correspond to random state  59 is 0.6896036993932741
# R2 score correspond to random state  59 is 0.5980660509123644
# R2 score correspond to random state  59 is 0.16961799225305818
# R2 score correspond to random state  59 is 0.7252109640495201
# R2 score correspond to random state  60 is 0.6216403497891573
# R2 score correspond to random state  60 is 0.7262489318829002
# R2 score correspond to random state  60 is 0.6051924678614231
# R2 score correspond to random state  60 is 0.17309043791130962
# R2 score correspond to random state  60 is 0.7693017513795651
# R2 score correspond to random state  61 is 0.5708842433017636
# R2 score correspond to random state  61 is 0.6309648291192418
# R2 score correspond to random state  61 is 0.5696239685361159
# R2 score correspond to random state  61 is 0.1744317772073909
# R2 score correspond to random state  61 is 0.674067862084146
# R2 score correspond to random state  62 is 0.5961093315348408
# R2 score correspond to random state  62 is 0.6564576243920213
# R2 score correspond to random state  62 is 0.5552205248305826
# R2 score correspond to random state  62 is 0.1658857285570956
# R2 score correspond to random state  62 is 0.7081731798441742
# R2 score correspond to random state  63 is 0.6272112192243808
# R2 score correspond to random state  63 is 0.7264692668394638
# R2 score correspond to random state  63 is 0.5896598888482814
# R2 score correspond to random state  63 is 0.14927032441687293
# R2 score correspond to random state  63 is 0.7316877760257768
# R2 score correspond to random state  64 is 0.5741727299609792
# R2 score correspond to random state  64 is 0.7240821999881332
# R2 score correspond to random state  64 is 0.5704885127152629
# R2 score correspond to random state  64 is 0.13139053805977163
# R2 score correspond to random state  64 is 0.7186514663935315
# R2 score correspond to random state  65 is 0.5640457136655957
# R2 score correspond to random state  65 is 0.6844003437625046
# R2 score correspond to random state  65 is 0.5611589865645212
# R2 score correspond to random state  65 is 0.16297315572594495
# R2 score correspond to random state  65 is 0.713892514631489
# R2 score correspond to random state  66 is 0.6886808713173923
# R2 score correspond to random state  66 is 0.7027846174373915
# R2 score correspond to random state  66 is 0.6084885613768283
# R2 score correspond to random state  66 is 0.16260700781065374
# R2 score correspond to random state  66 is 0.7393047008765913
# R2 score correspond to random state  67 is 0.6593896489243796
# R2 score correspond to random state  67 is 0.7419602665146838
# R2 score correspond to random state  67 is 0.6138488739466172
# R2 score correspond to random state  67 is 0.15468586097068626
# R2 score correspond to random state  67 is 0.727157104061209
# R2 score correspond to random state  68 is 0.6635664072947651
# R2 score correspond to random state  68 is 0.7352456437848702
# R2 score correspond to random state  68 is 0.6289144951888388
# R2 score correspond to random state  68 is 0.16862428730936052
# R2 score correspond to random state  68 is 0.7665298576783686
# R2 score correspond to random state  69 is 0.6725717897084502
# R2 score correspond to random state  69 is 0.6833709144743778
# R2 score correspond to random state  69 is 0.5465162280401532
# R2 score correspond to random state  69 is 0.1274076376622305
# R2 score correspond to random state  69 is 0.7027415657023632
# R2 score correspond to random state  70 is 0.6215639401146136
# R2 score correspond to random state  70 is 0.7067665276028811
# R2 score correspond to random state  70 is 0.6120288051316938
# R2 score correspond to random state  70 is 0.17602823153949743
# R2 score correspond to random state  70 is 0.7197742851657911
# R2 score correspond to random state  71 is 0.5958628980074134
# R2 score correspond to random state  71 is 0.6836631380800924
# R2 score correspond to random state  71 is 0.5986707250616294
# R2 score correspond to random state  71 is 0.1971707334097602
# R2 score correspond to random state  71 is 0.7281694027880506
# R2 score correspond to random state  72 is 0.6661154152620516
# R2 score correspond to random state  72 is 0.7104029845408627
# R2 score correspond to random state  72 is 0.5451313807360085
# R2 score correspond to random state  72 is 0.12313313902319012
# R2 score correspond to random state  72 is 0.7007956799602414
# R2 score correspond to random state  73 is 0.6474816173289487
# R2 score correspond to random state  73 is 0.7067288906460829
# R2 score correspond to random state  73 is 0.6096826888711047
# R2 score correspond to random state  73 is 0.15085341202948055
# R2 score correspond to random state  73 is 0.7284615046062584
# R2 score correspond to random state  74 is 0.6965509395797405
# R2 score correspond to random state  74 is 0.6845514581563445
# R2 score correspond to random state  74 is 0.6067243858117127
# R2 score correspond to random state  74 is 0.1716230424668902
# R2 score correspond to random state  74 is 0.7402431036386466
# R2 score correspond to random state  75 is 0.6479897772622216
# R2 score correspond to random state  75 is 0.746319489025798
# R2 score correspond to random state  75 is 0.6257644817734564
# R2 score correspond to random state  75 is 0.14925642907118564
# R2 score correspond to random state  75 is 0.7316537320148842
# R2 score correspond to random state  76 is 0.6457463164696118
# R2 score correspond to random state  76 is 0.7149419907717647
# R2 score correspond to random state  76 is 0.5593337507311178
# R2 score correspond to random state  76 is 0.14458277021442967
# R2 score correspond to random state  76 is 0.6935864465432249
# R2 score correspond to random state  77 is 0.5531944992852186
# R2 score correspond to random state  77 is 0.6781969097201779
# R2 score correspond to random state  77 is 0.563471738213802
# R2 score correspond to random state  77 is 0.14127491662933145
# R2 score correspond to random state  77 is 0.6923779366049372
# R2 score correspond to random state  78 is 0.5715677017600711
# R2 score correspond to random state  78 is 0.7285570190108581
# R2 score correspond to random state  78 is 0.6088823349288962
# R2 score correspond to random state  78 is 0.1537076791979487
# R2 score correspond to random state  78 is 0.7329441393996101
# R2 score correspond to random state  79 is 0.6574784756882823
# R2 score correspond to random state  79 is 0.7309883261838244
# R2 score correspond to random state  79 is 0.5981222952642424
# R2 score correspond to random state  79 is 0.16410820790495362
# R2 score correspond to random state  79 is 0.7300412199290516
# R2 score correspond to random state  80 is 0.6541195238092212
# R2 score correspond to random state  80 is 0.6747202625915667
# R2 score correspond to random state  80 is 0.5427997164314706
# R2 score correspond to random state  80 is 0.18130953958175022
# R2 score correspond to random state  80 is 0.722515754407377
# R2 score correspond to random state  81 is 0.5377680004828846
# R2 score correspond to random state  81 is 0.7010683861824105
# R2 score correspond to random state  81 is 0.582426297355006
# R2 score correspond to random state  81 is 0.13976960743575184
# R2 score correspond to random state  81 is 0.6749513307049234
# R2 score correspond to random state  82 is 0.6634692709308
# R2 score correspond to random state  82 is 0.7200646142620062
# R2 score correspond to random state  82 is 0.6124014798257469
# R2 score correspond to random state  82 is 0.1865532548859835
# R2 score correspond to random state  82 is 0.7495578349664653
# R2 score correspond to random state  83 is 0.47403161411197847
# R2 score correspond to random state  83 is 0.7192279206063402
# R2 score correspond to random state  83 is 0.5742863394097831
# R2 score correspond to random state  83 is 0.08061035187098065
# R2 score correspond to random state  83 is 0.7213377159605482
# R2 score correspond to random state  84 is 0.5940294579102756
# R2 score correspond to random state  84 is 0.7026180050955493
# R2 score correspond to random state  84 is 0.6002249060181228
# R2 score correspond to random state  84 is 0.17455556061156774
# R2 score correspond to random state  84 is 0.7026510461633599
# R2 score correspond to random state  85 is 0.6634054011462717
# R2 score correspond to random state  85 is 0.7281892086749584
# R2 score correspond to random state  85 is 0.6163257007918399
# R2 score correspond to random state  85 is 0.08822962629255038
# R2 score correspond to random state  85 is 0.7394110812043946
# R2 score correspond to random state  86 is 0.6006950167501617
# R2 score correspond to random state  86 is 0.6522196541378258
# R2 score correspond to random state  86 is 0.5851601849547023
# R2 score correspond to random state  86 is 0.15636266498126516
# R2 score correspond to random state  86 is 0.6970292493974031
# R2 score correspond to random state  87 is 0.6434423063026424
# R2 score correspond to random state  87 is 0.7466329728326264
# R2 score correspond to random state  87 is 0.5891717412944313
# R2 score correspond to random state  87 is 0.16162934665800466
# R2 score correspond to random state  87 is 0.7516338923503711
# R2 score correspond to random state  88 is 0.5956835711695668
# R2 score correspond to random state  88 is 0.7235580842304803
# R2 score correspond to random state  88 is 0.5911293874540277
# R2 score correspond to random state  88 is 0.17516595476773456
# R2 score correspond to random state  88 is 0.7328887538316752
# R2 score correspond to random state  89 is 0.6074235029971231
# R2 score correspond to random state  89 is 0.7284942107618757
# R2 score correspond to random state  89 is 0.5722789242268789
# R2 score correspond to random state  89 is 0.13787834452726633
# R2 score correspond to random state  89 is 0.7113256827031997
# max R2 score correspond to random state  60 is 0.7693017513795651 and model is GradientBoostingRegressor()

# %%
KNN = KNeighborsRegressor(n_neighbors=2)
KNN.fit(train_x,train_y)
pred = KNN.predict(test_x)
r2_sc = r2_score(test_y,pred)
print("R2 Score :",r2_sc*100)
# Out:
# R2 Score : 68.17491688292672

# %%
print('Mean Absolute Error: ', mean_absolute_error(test_y,pred))
print('Mean squared Error: ', mean_squared_error(test_y,pred))
print('Root Mean Absolute Error: ', np.sqrt(mean_absolute_error(test_y,pred)))
# Out:
# Mean Absolute Error:  0.0688622754491018
# Mean squared Error:  0.010775848303393213
# Root Mean Absolute Error:  0.2624162255827596

# %%
#importing library for classification prediction
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
#assign the value of x and y for training and testing phase
x_c = df.drop(columns=['region','Date'])
y_c = df[["region"]]
print(x_c.shape)
print(y_c.shape)
# Out:
# (1517, 12)
# (1517, 1)

# %%
#Standardize the value of x so that mean will 0 and SD will become 1 , and make the data as normal distributed
sc = StandardScaler()
sc.fit_transform(x_c)
x_c = pd.DataFrame(x_c,columns=x_c.columns)

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeClassifier(),KNeighborsClassifier()]
max_accuracy_score = 0
for r_state in range(40,90):
    train_xc,test_xc,train_yc,test_yc = train_test_split(x_c,y_c,random_state = r_state,test_size = 0.33)
    for i_c in model:
        i_c.fit(train_xc,train_yc)
        pre_c = i_c.predict(test_xc)
        ac_score = accuracy_score(test_yc,pre_c)
        print("accuracy score correspond to random state " ,r_state ,"is", ac_score)
        if ac_score> max_accuracy_score:
            max_accuracy_score=ac_score
            final_state = r_state
            final_model = i_c
            
print()
print()
print()
print()

print("max accuracy score correspond to random state " ,final_state , "is" , max_accuracy_score ,"and model is",final_model)
# Out:
# accuracy score correspond to random state  40 is 0.874251497005988
# accuracy score correspond to random state  40 is 0.8243512974051896
# accuracy score correspond to random state  41 is 0.8782435129740519
# accuracy score correspond to random state  41 is 0.8043912175648703
# accuracy score correspond to random state  42 is 0.8682634730538922
# accuracy score correspond to random state  42 is 0.8163672654690619
# accuracy score correspond to random state  43 is 0.9041916167664671
# accuracy score correspond to random state  43 is 0.8303393213572854
# accuracy score correspond to random state  44 is 0.844311377245509
# accuracy score correspond to random state  44 is 0.8043912175648703
# accuracy score correspond to random state  45 is 0.8483033932135728
# accuracy score correspond to random state  45 is 0.8003992015968064
# accuracy score correspond to random state  46 is 0.8642714570858283
# accuracy score correspond to random state  46 is 0.7924151696606786
# accuracy score correspond to random state  47 is 0.8782435129740519
# accuracy score correspond to random state  47 is 0.8363273453093812
# accuracy score correspond to random state  48 is 0.8562874251497006
# accuracy score correspond to random state  48 is 0.7964071856287425
# accuracy score correspond to random state  49 is 0.8582834331337326
# accuracy score correspond to random state  49 is 0.8163672654690619
# accuracy score correspond to random state  50 is 0.8782435129740519
# accuracy score correspond to random state  50 is 0.7904191616766467
# accuracy score correspond to random state  51 is 0.874251497005988
# accuracy score correspond to random state  51 is 0.7904191616766467
# accuracy score correspond to random state  52 is 0.8502994011976048
# accuracy score correspond to random state  52 is 0.7924151696606786
# accuracy score correspond to random state  53 is 0.846307385229541
# accuracy score correspond to random state  53 is 0.7784431137724551
# accuracy score correspond to random state  54 is 0.8582834331337326
# accuracy score correspond to random state  54 is 0.8163672654690619
# accuracy score correspond to random state  55 is 0.8702594810379242
# accuracy score correspond to random state  55 is 0.8243512974051896
# accuracy score correspond to random state  56 is 0.8582834331337326
# accuracy score correspond to random state  56 is 0.7964071856287425
# accuracy score correspond to random state  57 is 0.8343313373253493
# accuracy score correspond to random state  57 is 0.7924151696606786
# accuracy score correspond to random state  58 is 0.8263473053892215
# accuracy score correspond to random state  58 is 0.8003992015968064
# accuracy score correspond to random state  59 is 0.872255489021956
# accuracy score correspond to random state  59 is 0.8163672654690619
# accuracy score correspond to random state  60 is 0.8902195608782435
# accuracy score correspond to random state  60 is 0.8323353293413174
# accuracy score correspond to random state  61 is 0.874251497005988
# accuracy score correspond to random state  61 is 0.7784431137724551
# accuracy score correspond to random state  62 is 0.8582834331337326
# accuracy score correspond to random state  62 is 0.8083832335329342
# accuracy score correspond to random state  63 is 0.8862275449101796
# accuracy score correspond to random state  63 is 0.8363273453093812
# accuracy score correspond to random state  64 is 0.8862275449101796
# accuracy score correspond to random state  64 is 0.8163672654690619
# accuracy score correspond to random state  65 is 0.8383233532934131
# accuracy score correspond to random state  65 is 0.8183632734530938
# accuracy score correspond to random state  66 is 0.8622754491017964
# accuracy score correspond to random state  66 is 0.8083832335329342
# accuracy score correspond to random state  67 is 0.8902195608782435
# accuracy score correspond to random state  67 is 0.8163672654690619
# accuracy score correspond to random state  68 is 0.8782435129740519
# accuracy score correspond to random state  68 is 0.810379241516966
# accuracy score correspond to random state  69 is 0.8502994011976048
# accuracy score correspond to random state  69 is 0.8163672654690619
# accuracy score correspond to random state  70 is 0.8522954091816367
# accuracy score correspond to random state  70 is 0.7964071856287425
# accuracy score correspond to random state  71 is 0.8782435129740519
# accuracy score correspond to random state  71 is 0.8183632734530938
# accuracy score correspond to random state  72 is 0.844311377245509
# accuracy score correspond to random state  72 is 0.7844311377245509
# accuracy score correspond to random state  73 is 0.8383233532934131
# accuracy score correspond to random state  73 is 0.7844311377245509
# accuracy score correspond to random state  74 is 0.8522954091816367
# accuracy score correspond to random state  74 is 0.7784431137724551
# accuracy score correspond to random state  75 is 0.8682634730538922
# accuracy score correspond to random state  75 is 0.8003992015968064
# accuracy score correspond to random state  76 is 0.9021956087824351
# accuracy score correspond to random state  76 is 0.8223552894211577
# accuracy score correspond to random state  77 is 0.8702594810379242
# accuracy score correspond to random state  77 is 0.812375249500998
# accuracy score correspond to random state  78 is 0.8642714570858283
# accuracy score correspond to random state  78 is 0.8223552894211577
# accuracy score correspond to random state  79 is 0.8522954091816367
# accuracy score correspond to random state  79 is 0.8083832335329342
# accuracy score correspond to random state  80 is 0.8662674650698603
# accuracy score correspond to random state  80 is 0.8243512974051896
# accuracy score correspond to random state  81 is 0.8702594810379242
# accuracy score correspond to random state  81 is 0.7904191616766467
# accuracy score correspond to random state  82 is 0.8602794411177644
# accuracy score correspond to random state  82 is 0.7844311377245509
# accuracy score correspond to random state  83 is 0.8642714570858283
# accuracy score correspond to random state  83 is 0.8263473053892215
# accuracy score correspond to random state  84 is 0.8343313373253493
# accuracy score correspond to random state  84 is 0.7984031936127745
# accuracy score correspond to random state  85 is 0.8582834331337326
# accuracy score correspond to random state  85 is 0.8083832335329342
# accuracy score correspond to random state  86 is 0.8602794411177644
# accuracy score correspond to random state  86 is 0.8063872255489022
# accuracy score correspond to random state  87 is 0.8562874251497006
# accuracy score correspond to random state  87 is 0.8083832335329342
# accuracy score correspond to random state  88 is 0.8622754491017964
# accuracy score correspond to random state  88 is 0.7944111776447106
# accuracy score correspond to random state  89 is 0.846307385229541
# accuracy score correspond to random state  89 is 0.8163672654690619
#
#
#
#
# max accuracy score correspond to random state  43 is 0.9041916167664671 and model is DecisionTreeClassifier()

# %%
KNC = KNeighborsClassifier(n_neighbors=1)
KNC.fit(train_xc,train_yc)
predc = KNC.predict(test_xc)
acu_score = accuracy_score(test_yc,predc)
print("Accuracy Score :",acu_score*100)
# Out:
# Accuracy Score : 84.83033932135729

# %%
#Calculating the scores of different parameters
score = cross_val_score(KNC,x_c,y_c,cv = 10,scoring='accuracy').mean()
print('Cross_val_score : ', score*100)
print('Mean Score      : ' , score.mean()*100)
print('STD score       : ' , score.std())
# Out:
# Cross_val_score :  82.80193447194144
# Mean Score      :  82.80193447194144
# STD score       :  0.0

# %%
import pickle
filename="Avacado_project.csv"
pickle.dump(KNC,open(filename,"wb"))
