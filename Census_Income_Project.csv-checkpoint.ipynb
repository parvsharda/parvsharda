# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the dataset

# %%
df=pd.read_csv("Census_Income_Project.csv")

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0           0.0           0.0            13.0   United-States   <=50K
# ...

# %%
df.shape
# Out:
# (12023, 15)

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                 int64
# Workclass          object
# Fnlwgt              int64
# Education          object
# Education_num       int64
# Marital_status     object
# Occupation         object
# Relationship       object
# Race               object
# Sex                object
# Capital_gain      float64
# Capital_loss      float64
# Hours_per_week    float64
# Native_country     object
# Income             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        1
# Relationship      1
# Race              1
# Sex               1
# Capital_gain      1
# Capital_loss      1
# Hours_per_week    1
# Native_country    1
# Income            1
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
#The above data shows that there are some missing values in the dataset

# %%
#filling the null values
#for Categorical data we will be using mode and for continous we will replace nulll values with mean

# %%
df['Occupation']=df['Occupation'].fillna(df['Occupation'].mode()[0])
df['Relationship']=df['Relationship'].fillna(df['Relationship'].mode()[0])
df['Race']=df['Race'].fillna(df['Race'].mode()[0])
df['Sex']=df['Sex'].fillna(df['Sex'].mode()[0])
df['Native_country']=df['Native_country'].fillna(df['Native_country'].mode()[0])
df['Income']=df['Income'].fillna(df['Income'].mode()[0])

# %%
df['Capital_gain']=df['Capital_gain'].fillna(df['Capital_gain'].mean())
df['Capital_loss']=df['Capital_loss'].fillna(df['Capital_loss'].mean())
df['Hours_per_week']=df['Hours_per_week'].fillna(df['Hours_per_week'].mean())

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#The above stats shos that there are no null values left

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  12023.000000  1.202300e+04    12023.00000  12023.000000  12023.000000
# mean      38.475006  1.901677e+05       10.07835   1042.332973     89.220596
# std       13.610366  1.048379e+05        2.54855   7177.868743    404.662831
# min       17.000000  1.921400e+04        1.00000      0.000000      0.000000
# 25%       28.000000  1.184025e+05        9.00000      0.000000      0.000000
# 50%       37.000000  1.790080e+05       10.00000      0.000000      0.000000
# 75%       47.000000  2.389120e+05       12.00000      0.000000      0.000000
# max       90.000000  1.226583e+06       16.00000  99999.000000   4356.000000
#
#        Hours_per_week
# count    12023.000000
# mean        40.526951
# std         12.302605
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # Data Visualisation

# %%
sns.countplot(y='Workclass',hue='Income',data=df)

# %%
#The above data shows that private workclass is leading in both categories

# %%
sns.countplot(y='Sex',hue='Income',data=df)

# %%
# The above data shows that males are the majority in the dataset and males are leading in both features i.e. Income > 50K and Income <=50K

# %%
sns.countplot(y='Education',hue='Income',data=df)

# %%
#The above data shows that HS-grad education holding population is the majority population having Income<=50K in the dataset and on the other hand Bachelors education holding population is having the largest number of population hving Income >50K in the datset

# %%
sns.countplot(y='Marital_status',hue='Income',data=df)

# %%
# the above data shows that Married-civ-spouse marital_status population is having the largest number of population having Income >50K and on the other hand never married Marital_status is having the highest number of population having Income<=50K

# %%
sns.countplot(y='Race',hue='Income',data=df)

# %%
# The above data shows that White race is dominating in both features in the given dateset

# %%
sns.countplot(y='Native_country',hue='Income',data=df)

# %%
#United States is dominating as per the data in both features

# %% [markdown]
# # Coorelation Matrix

# %%
df.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.006434 -0.073868  -0.018640       0.028725
# Workclass       0.006434   1.000000 -0.015966   0.017604       0.054561
# Fnlwgt         -0.073868  -0.015966  1.000000  -0.040299      -0.048036
# Education      -0.018640   0.017604 -0.040299   1.000000       0.353718
# Education_num   0.028725   0.054561 -0.048036   0.353718       1.000000
# Marital_status -0.257716  -0.066695  0.038360  -0.026853      -0.060543
# Occupation     -0.020854   0.255037  0.002497  -0.025911       0.109204
# Relationship   -0.256302  -0.089847  0.010166  -0.005091      -0.093500
# Race            0.021908   0.038575 -0.023959   0.017426       0.034385
# Sex             0.082387   0.088761  0.035241  -0.029370       0.015707
# Capital_gain    0.062636   0.036646  0.001558   0.033139       0.121102
# Capital_loss    0.057487   0.008460 -0.011522   0.015897       0.080771
# ...

# %%
corr=df.corr()
fig,ax=plt.subplots(figsize=(15,15))
sns.heatmap(corr,annot=True,ax=ax)

# %%
sns.pairplot(df)

# %%
df.skew()
# Out:
# Age                0.588144
# Workclass         -0.754519
# Fnlwgt             1.315426
# Education         -0.957025
# Education_num     -0.305141
# Marital_status    -0.021088
# Occupation         0.102740
# Relationship       0.786775
# Race              -2.472808
# Sex               -0.733028
# Capital_gain      12.234436
# Capital_loss       4.484678
# Hours_per_week     0.182431
# Native_country    -3.622537
# Income             1.223341
# dtype: float64

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
columns=['Workclass','Education','Marital_status','Occupation','Relationship','Race','Sex','Native_country','Income']
le=LabelEncoder()
for col in columns:
    df[col]=le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1           0.0           0.0
# 1           6             1     4    1           0.0           0.0
# 2           6             0     2    1           0.0           0.0
# 3          10             5     2    0           0.0           0.0
# 4           4             5     4    0           0.0           0.0
#
#    Hours_per_week  Native_country  Income
# 0            13.0              38       0
# 1            40.0              38       0
# ...

# %% [markdown]
# # Checking Outliers in the dataset

# %%
df.plot(kind='box',figsize=(12,12),layout=(4,4),subplots=True)
# Out:
# Age                   AxesSubplot(0.125,0.71587;0.168478x0.16413)
# Workclass          AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# Fnlwgt             AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# Education          AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# Education_num        AxesSubplot(0.125,0.518913;0.168478x0.16413)
# Marital_status    AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# Occupation        AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# Relationship      AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# Race                 AxesSubplot(0.125,0.321957;0.168478x0.16413)
# Sex               AxesSubplot(0.327174,0.321957;0.168478x0.16413)
# Capital_gain      AxesSubplot(0.529348,0.321957;0.168478x0.16413)
# Capital_loss      AxesSubplot(0.731522,0.321957;0.168478x0.16413)
# Hours_per_week          AxesSubplot(0.125,0.125;0.168478x0.16413)
# Native_country       AxesSubplot(0.327174,0.125;0.168478x0.16413)
# ...

# %%
# there are a lot of outliers in the above dataset

# %%
fig,ax=plt.subplots(ncols=5,nrows=3,figsize=(15,15))
index=0
ax=ax.flatten()

for col, value in df.items():
    sns.distplot(value,ax=ax[index])
    index +=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %% [markdown]
# # Min Max Normalization

# %%
cols=['Capital_gain','Capital_loss','Native_country','Race','Relationship']
for col in cols:
    minimum=min(df[col])
    maximum=max(df[col])
    df[col]=(df[col]-minimum)/(maximum-minimum)

# %%
fig,ax=plt.subplots(ncols=5,nrows=3,figsize=(15,15))
index=0
ax=ax.flatten()

for col, value in df.items():
    sns.distplot(value,ax=ax[index])
    index +=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
#Standardize the value of x so that mean will 0 and SD will become 1 , and make the data as normal distributed
sc = StandardScaler()
sc.fit_transform(x)
x = pd.DataFrame(x,columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
#assign the value of x and y for training and testing phase
x = df.drop(columns=['Income'])
y = df[["Income"]]
print(x.shape)
print(y.shape)
# Out:
# (12023, 14)
# (12023, 1)

# %% [markdown]
# # Training the model

# %%
from sklearn.model_selection import cross_val_score
def classify(model,x,y):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
    model.fit(x_train,y_train)
    print("Accuracy",model.score(x_test,y_test)*100)
    score=cross_val_score(model,x,y,cv=5)
    print("Cross Validation",np.mean(score)*100)

# %% [raw]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
classify(model,x,y)
# Out:
# Accuracy 75.46777546777547
# Cross Validation 76.08749796769764

# %% [raw]
# DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
classify(model,x,y)
# Out:
# Accuracy 81.08108108108108
# Cross Validation 80.50399369034974

# %% [raw]
# RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
classify(model,x,y)
# Out:
# Accuracy 84.86486486486487
# Cross Validation 85.2366291800568

# %% [raw]
# ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
model=ExtraTreesClassifier()
classify(model,x,y)
# Out:
# Accuracy 83.74220374220374
# Cross Validation 83.62309179780063

# %% [markdown]
# # Best_Model

# %%
best_model=RandomForestClassifier()

# %%
import pickle
filename="Census_Income_Project.csv"
pickle.dump(best_model,open(filename,"wb"))
