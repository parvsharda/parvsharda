# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the dataset

# %%
df=pd.read_csv("Baseball.csv")

# %%
df.head(10)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5  93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6  87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7  81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8  80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9  78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86
# 5  34   88
# 6  48   93
# 7  43   77
# 8  60   95
# 9  40   97

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# No null values in the data

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# # Data Visualisation

# %%
plt.scatter(df['R'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# From the above plot we can see there is a positive relation between Runs "R" and Wins "W"

# %%
plt.scatter(df['AB'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# Not getting clear information from above plot

# %%
plt.scatter(df['2B'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# The above plot shows positive relation between Doubles and Wins

# %%
plt.scatter(df['3B'],df['W'],color='g',alpha=0.6)

# %%
plt.scatter(df['HR'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# The above plot shows some positive relation

# %%
plt.scatter(df['BB'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# The above plot shows some positive relation

# %%
plt.scatter(df['SO'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# The above plot shows some positive relation

# %%
plt.scatter(df['SB'],df['W'],color='g',alpha=0.6)

# %%
plt.scatter(df['RA'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# The above plot shows negetive relation

# %%
plt.scatter(df['ER'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# The above plot shows negetive relation

# %%
plt.scatter(df['ERA'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# The above plot shows negetive relation

# %%
plt.scatter(df['CG'],df['W'],color='g',alpha=0.6)

# %%
plt.scatter(df['SHO'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# Shows some positive relation

# %%
plt.scatter(df['SV'],df['W'],color='g',alpha=0.6)

# %% [markdown]
# Shows some positive relation

# %%
plt.scatter(df['E'],df['W'],color='g',alpha=0.6)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
sns.distplot(df["W"])

# %%
sns.distplot(df["R"])

# %%
sns.distplot(df["AB"])

# %%
sns.distplot(df["H"])

# %%
sns.distplot(df["2B"])

# %%
sns.distplot(df["3B"])

# %%
sns.distplot(df["HR"])

# %%
sns.distplot(df["BB"])

# %%
sns.distplot(df["SB"])

# %%
sns.distplot(df["SO"])

# %%
sns.distplot(df["RA"])

# %%
sns.distplot(df['ER'])

# %%
sns.distplot(df["ERA"])

# %%
sns.distplot(df["CG"])

# %%
sns.distplot(df["SHO"])

# %%
sns.distplot(df["SV"])

# %%
sns.distplot(df["E"])

# %% [markdown]
# The above plots shows that the data is not normalised.

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# Z-Score Technique

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
# Percentage Data Loss

# %%
loss_percent=(30-29)/30*100
print(loss_percent)
# Out:
# 3.3333333333333335

# %% [markdown]
# Dividing data in features and vectors

# %%
x=df_new.drop("W",axis=1)
y=df_new['W']

# %% [markdown]
# # Linear Regresssion

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state{i},the training accuracy is:-{r2_score(y_train,pred_train)}")
    print(f"At random state{i},the testing accuracy is:-{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state0,the training accuracy is:-0.979301718690075
# At random state0,the testing accuracy is:-0.3764241202412736
#
#
# At random state1,the training accuracy is:-0.96935160044487
# At random state1,the testing accuracy is:-0.755524141490966
#
#
# At random state2,the training accuracy is:-0.9664881232216758
# At random state2,the testing accuracy is:--0.32929092499060153
#
#
# At random state3,the training accuracy is:-0.9534657143080705
# At random state3,the testing accuracy is:-0.8485894004114063
#
#
# At random state4,the training accuracy is:-0.9611298547801514
# At random state4,the testing accuracy is:-0.7514775069642535
#
#
# At random state5,the training accuracy is:-0.9617989022273271
# At random state5,the testing accuracy is:-0.5545096693427655
#
#
# At random state6,the training accuracy is:-0.960321770783519
# At random state6,the testing accuracy is:-0.7473255183244814
#
#
# At random state7,the training accuracy is:-0.9590946505307433
# At random state7,the testing accuracy is:-0.4043749564143736
#
#
# At random state8,the training accuracy is:-0.98192239697125
# At random state8,the testing accuracy is:-0.6503293907997015
#
#
# At random state9,the training accuracy is:-0.9852222148496504
# At random state9,the testing accuracy is:-0.37465833779136926
#
#
# At random state10,the training accuracy is:-0.9817910208904364
# At random state10,the testing accuracy is:-0.17817265572154484
#
#
# At random state11,the training accuracy is:-0.9641001310696609
# At random state11,the testing accuracy is:-0.24948171885985737
#
#
# At random state12,the training accuracy is:-0.9758100123592066
# At random state12,the testing accuracy is:-0.6488860213020535
#
#
# At random state13,the training accuracy is:-0.9503913607770883
# At random state13,the testing accuracy is:-0.7096176324298296
#
#
# At random state14,the training accuracy is:-0.9581166229280103
# At random state14,the testing accuracy is:-0.7326465137567668
#
#
# At random state15,the training accuracy is:-0.973796224978541
# At random state15,the testing accuracy is:-0.6981784724670711
#
#
# At random state16,the training accuracy is:-0.9866574499377259
# At random state16,the testing accuracy is:-0.279385183669871
#
#
# At random state17,the training accuracy is:-0.9539846486283632
# At random state17,the testing accuracy is:-0.7160067705365056
#
#
# At random state18,the training accuracy is:-0.9791203016424965
# At random state18,the testing accuracy is:-0.1922642254758531
#
#
# At random state19,the training accuracy is:-0.9708530864297662
# At random state19,the testing accuracy is:--0.16713372118429604
#
#
# At random state20,the training accuracy is:-0.9849511032695474
# At random state20,the testing accuracy is:--1.085593521317406
#
#
# At random state21,the training accuracy is:-0.9852477635221244
# At random state21,the testing accuracy is:-0.11711474124891563
#
#
# At random state22,the training accuracy is:-0.9595022287889581
# At random state22,the testing accuracy is:-0.6870624488866033
#
#
# At random state23,the training accuracy is:-0.9761439999329892
# At random state23,the testing accuracy is:-0.4347687655074858
#
#
# At random state24,the training accuracy is:-0.9693968771592167
# At random state24,the testing accuracy is:--1.0312920828230774
#
#
# At random state25,the training accuracy is:-0.9665196720646336
# At random state25,the testing accuracy is:-0.054051142490583515
#
#
# At random state26,the training accuracy is:-0.9573762003455404
# At random state26,the testing accuracy is:-0.5976868922276983
#
#
# At random state27,the training accuracy is:-0.9780600973626669
# At random state27,the testing accuracy is:-0.7164961060453637
#
#
# At random state28,the training accuracy is:-0.9851836075682533
# At random state28,the testing accuracy is:--0.08363002009034592
#
#
# At random state29,the training accuracy is:-0.9597282352007812
# At random state29,the testing accuracy is:-0.7911384894366719
#
#
# At random state30,the training accuracy is:-0.9509987369376942
# At random state30,the testing accuracy is:-0.8592555824297016
#
#
# At random state31,the training accuracy is:-0.9783784423180567
# At random state31,the testing accuracy is:-0.2874612499420791
#
#
# At random state32,the training accuracy is:-0.9753197700418504
# At random state32,the testing accuracy is:--0.05985745322266256
#
#
# At random state33,the training accuracy is:-0.9566731379573058
# At random state33,the testing accuracy is:-0.6767555583979183
#
#
# At random state34,the training accuracy is:-0.9837618671808753
# At random state34,the testing accuracy is:-0.4257576294655744
#
#
# At random state35,the training accuracy is:-0.97732235238902
# At random state35,the testing accuracy is:-0.8268955790694537
#
#
# At random state36,the training accuracy is:-0.9828084384653819
# At random state36,the testing accuracy is:--0.3739910937582158
#
#
# At random state37,the training accuracy is:-0.982727795738601
# At random state37,the testing accuracy is:--0.025406405318306957
#
#
# At random state38,the training accuracy is:-0.9653052300486406
# At random state38,the testing accuracy is:-0.464608314626228
#
#
# At random state39,the training accuracy is:-0.9825079921085839
# At random state39,the testing accuracy is:-0.3055601447711933
#
#
# At random state40,the training accuracy is:-0.9850869323282816
# At random state40,the testing accuracy is:-0.2804861137148037
#
#
# At random state41,the training accuracy is:-0.9512167342792702
# At random state41,the testing accuracy is:-0.6922470788710688
#
#
# At random state42,the training accuracy is:-0.9669863192160298
# At random state42,the testing accuracy is:-0.25928395352759037
#
#
# At random state43,the training accuracy is:-0.9909439268440402
# At random state43,the testing accuracy is:--1.6579669952555216
#
#
# At random state44,the training accuracy is:-0.9661518619712495
# At random state44,the testing accuracy is:-0.4558826788653991
#
#
# At random state45,the training accuracy is:-0.9823651619519428
# At random state45,the testing accuracy is:-0.32012734423395295
#
#
# At random state46,the training accuracy is:-0.9564672221873488
# At random state46,the testing accuracy is:-0.6086791076001742
#
#
# At random state47,the training accuracy is:-0.9691355005828057
# At random state47,the testing accuracy is:-0.12752234038127475
#
#
# At random state48,the training accuracy is:-0.9781565249225681
# At random state48,the testing accuracy is:--0.14831681753770476
#
#
# At random state49,the training accuracy is:-0.9818481758067004
# At random state49,the testing accuracy is:--0.35525213965402846
#
#
# At random state50,the training accuracy is:-0.9497540816293273
# At random state50,the testing accuracy is:-0.8402586950388427
#
#
# At random state51,the training accuracy is:-0.9759446138806239
# At random state51,the testing accuracy is:-0.6782092587437505
#
#
# At random state52,the training accuracy is:-0.9808426179096355
# At random state52,the testing accuracy is:-0.38592101160345427
#
#
# At random state53,the training accuracy is:-0.9641741950951814
# At random state53,the testing accuracy is:-0.48815713664033755
#
#
# At random state54,the training accuracy is:-0.9730149138863147
# At random state54,the testing accuracy is:-0.08424908151314636
#
#
# At random state55,the training accuracy is:-0.9572482066538395
# At random state55,the testing accuracy is:-0.7900101384277827
#
#
# At random state56,the training accuracy is:-0.9755500288829789
# At random state56,the testing accuracy is:-0.6589140348288416
#
#
# At random state57,the training accuracy is:-0.9759205325791025
# At random state57,the testing accuracy is:-0.6079747434400411
#
#
# At random state58,the training accuracy is:-0.9817869712738102
# At random state58,the testing accuracy is:-0.5510265209086057
#
#
# At random state59,the training accuracy is:-0.9772225796142908
# At random state59,the testing accuracy is:-0.6634093644389668
#
#
# At random state60,the training accuracy is:-0.9895772197991747
# At random state60,the testing accuracy is:-0.08185322307411069
#
#
# At random state61,the training accuracy is:-0.978865960073174
# At random state61,the testing accuracy is:-0.6581517293978029
#
#
# At random state62,the training accuracy is:-0.9855012361896787
# At random state62,the testing accuracy is:-0.4811072849367978
#
#
# At random state63,the training accuracy is:-0.983053979193738
# At random state63,the testing accuracy is:-0.6389160925748376
#
#
# At random state64,the training accuracy is:-0.9498377203433127
# At random state64,the testing accuracy is:-0.855629095209568
#
#
# At random state65,the training accuracy is:-0.9801762997126915
# At random state65,the testing accuracy is:-0.3979366711628628
# At random state66,the training accuracy is:-0.9561260522887614
# At random state66,the testing accuracy is:-0.6498495975004335
#
#
# At random state67,the training accuracy is:-0.9518791307102044
# At random state67,the testing accuracy is:-0.8157368204801718
#
#
# At random state68,the training accuracy is:-0.9636311729119128
# At random state68,the testing accuracy is:--0.08171472137603164
#
#
# At random state69,the training accuracy is:-0.9627946030682473
# At random state69,the testing accuracy is:-0.47173279981731453
#
#
# At random state70,the training accuracy is:-0.9742526983397114
# At random state70,the testing accuracy is:--0.19345477116757404
#
#
# At random state71,the training accuracy is:-0.9881455904971489
# At random state71,the testing accuracy is:--4.526975628899014
#
#
# At random state72,the training accuracy is:-0.9655726874271956
# At random state72,the testing accuracy is:--0.44045894502754246
#
#
# At random state73,the training accuracy is:-0.9649260708896539
# At random state73,the testing accuracy is:-0.7675589097493201
#
#
# At random state74,the training accuracy is:-0.9682382951628077
# At random state74,the testing accuracy is:--0.1565227626726906
#
#
# At random state75,the training accuracy is:-0.9742058927656048
# At random state75,the testing accuracy is:-0.06853971821228633
#
#
# At random state76,the training accuracy is:-0.9727741782941949
# At random state76,the testing accuracy is:-0.5301458735053487
#
#
# At random state77,the training accuracy is:-0.9594808624040052
# At random state77,the testing accuracy is:-0.6872828258517405
#
#
# At random state78,the training accuracy is:-0.9603231553623605
# At random state78,the testing accuracy is:-0.46098163978561446
#
#
# At random state79,the training accuracy is:-0.9787922709284371
# At random state79,the testing accuracy is:-0.5525572590656491
#
#
# At random state80,the training accuracy is:-0.9760170103824864
# At random state80,the testing accuracy is:-0.507305832023047
#
#
# At random state81,the training accuracy is:-0.9783042200995691
# At random state81,the testing accuracy is:-0.7527407964239309
#
#
# At random state82,the training accuracy is:-0.9738621043538022
# At random state82,the testing accuracy is:-0.5262865332041249
#
#
# At random state83,the training accuracy is:-0.9812514305906167
# At random state83,the testing accuracy is:-0.1035916436386698
#
#
# At random state84,the training accuracy is:-0.9663196552084653
# At random state84,the testing accuracy is:-0.4038862767807321
#
#
# At random state85,the training accuracy is:-0.9662232024149717
# At random state85,the testing accuracy is:-0.24795105552167762
#
#
# At random state86,the training accuracy is:-0.9605204963879119
# At random state86,the testing accuracy is:--0.9931046091289322
#
#
# At random state87,the training accuracy is:-0.9592744629032905
# At random state87,the testing accuracy is:-0.47628206844136234
#
#
# At random state88,the training accuracy is:-0.9960807953835067
# At random state88,the testing accuracy is:--2.493371937894538
#
#
# At random state89,the training accuracy is:-0.9572247108513684
# At random state89,the testing accuracy is:-0.6047171241049558
#
#
# At random state90,the training accuracy is:-0.956903836108365
# At random state90,the testing accuracy is:-0.7715526011050631
#
#
# At random state91,the training accuracy is:-0.9872596506570489
# At random state91,the testing accuracy is:-0.5187820140376463
#
#
# At random state92,the training accuracy is:-0.9883764137712476
# At random state92,the testing accuracy is:-0.43308838842284947
#
#
# At random state93,the training accuracy is:-0.9633949980603782
# At random state93,the testing accuracy is:-0.663629094726374
#
#
# At random state94,the training accuracy is:-0.9671357299660741
# At random state94,the testing accuracy is:-0.6078565555491822
#
#
# At random state95,the training accuracy is:-0.9653570973775679
# At random state95,the testing accuracy is:-0.6344525313353582
#
#
# At random state96,the training accuracy is:-0.9900893827098423
# At random state96,the testing accuracy is:--0.3900254834826562
#
#
# At random state97,the training accuracy is:-0.9586699149043334
# At random state97,the testing accuracy is:-0.7342022365523883
#
#
# At random state98,the training accuracy is:-0.9892263010900146
# At random state98,the testing accuracy is:--0.6109960154989897
#
#
# At random state99,the training accuracy is:-0.9611734965562407
# At random state99,the testing accuracy is:-0.8458464532843923

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=30)

# %%
y_pred=lr.predict(x_train)
print("Training Accuracy:",lr.score(x_train,y_train)*100)
# Out:
# Training Accuracy: 95.40944408853142

# %%
print("Testing Accuracy:",lr.score(x_test,y_test)*100)
# Out:
# Testing Accuracy: 64.14431011650892

# %%
print("Model Accuracy:",r2_score(y,lr.predict(x))*100)
# Out:
# Model Accuracy: 86.2915786287326

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor()
reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=reg.predict(x_train)

# %%
print("Training Accuracy:",reg.score(x_train,y_train)*100)
# Out:
# Training Accuracy: 93.28710207140911

# %%
print("Testing Accuracy:",reg.score(x_test,y_test)*100)
# Out:
# Testing Accuracy: 54.89785804995058

# %%
print("Model Accuracy:",r2_score(y,reg.predict(x))*100)
# Out:
# Model Accuracy: 82.10472189227464

# %% [markdown]
# # Prediction and Final Score:

# %% [markdown]
# Linear Regression

# %% [markdown]
# Model Score: 86.29% Accuracy,
# Training Accuracy: 95.40% Accuracy,
# Testing Accuracy: 64.14% Accuracy

# %% [markdown]
# Random Forest Regressor

# %% [markdown]
# Model Score: 82.10% Accuracy, Training Accuracy: 93.28% Accuracy, Testing Accuracy: 54.89% Accuracy

# %%
import pickle
filename="Baseball_predicion.csv"
pickle.dump(lr,open(filename,"wb"))
