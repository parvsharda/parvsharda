# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the data

# %%
df=pd.read_csv("Wine_Quality.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
sns.scatterplot(x="fixed acidity",y="quality",data=df)

# %%
sns.scatterplot(x="volatile acidity",y="quality",data=df)

# %%
sns.scatterplot(x="citric acid",y="quality",data=df)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.hist(df.quality)
plt.title('Quality Distribution')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The above plot shows the distribution of the quality of the wine in the dataset, also represents that most of the wine is of average quality i.e. ranging between 5-6

# %%
plt.figure(figsize=(8,5))
sns.barplot(df['quality'],df['pH'])
plt.show()

# %% [raw]
# # From the barplot of quality vs ph we can visualize that there is a slight decrease in pH with the increase in quality of wine

# %%
sns.boxplot(x='quality',y='pH',data=df)
plt.title("Boxplot of Quality and pH")
plt.show()

# %%
sns.boxplot(x='quality',y='alcohol',data=df)
plt.title("Boxplot of Quality and Alcohol")
plt.show()

# %% [raw]
# # The above plot shows the increase in the quality of wine with increase in alcohol. The quality of wine is directly related to the amount of alcohol in wine. More alcohol in the wine better the quality.

# %%
sns.boxplot(x="quality",y="residual sugar",data=df)
plt.title("Boxplot of Quality and residual sugar")
plt.show()

# %% [raw]
# There is not much effect of residual sugar on the quality of wine

# %%
sns.boxplot(x="quality",y="density",data=df)
plt.title("Boxplot of Quality and Density")
plt.show()

# %% [raw]
# Lower the density of wine better will be the quality of wine. From the above boxplot we can visualize that the quality of wine increases with decrease in density.

# %%
sns.boxplot(x="quality",y="sulphates",data=df)
plt.title("Boxplot of Quality and Sulphates")
plt.show()

# %% [raw]
# The above plot represents that the quality of alcohol increases with the increase in the amount of sulphates in the wine.

# %%
sns.boxplot(x="quality",y="chlorides",data=df)
plt.title("Boxplot of Quality and Chlorides")
plt.show()

# %% [raw]
# From the above plot we can see that there is not even a slight change in the quality of wine for a particular amount of chlorides mixed in them.

# %%
sns.boxplot(x="quality",y="citric acid",data=df)
plt.title("Boxplot of quality and citric acid")
plt.show()

# %% [raw]
# The quality of wine increases with the increase of amount of citric acid in the wine.

# %%
sns.boxplot(x="quality",y="volatile acidity",data=df)
plt.title("Boxplot of quality and volatile acidity")
plt.show()

# %% [raw]
# From the above boxplot we can see that the quality of wine increases with the decrease in the amount of volatile acids.

# %%
sns.boxplot(x="quality",y="fixed acidity",data=df)
plt.title("Boxplot of quality and fixed acidity")
plt.show()

# %% [raw]
# There is not much effect of fixed acidity on quality of wine.

# %%
from sklearn.model_selection import cross_val_score, train_test_split
def classify(model,x,y):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=48)
    #train the model
    model.fit(x_train,y_train)
    print("Accuracy:",model.score(x_test,y_test)*100)
    
    #cross validation
    score=cross_val_score(model,x,y,cv=5)
    print("CV Score:",np.mean(score)*100)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model,x,y)
# Out:
# C:\Users\PARV SHARDA\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 59.5
# C:\Users\PARV SHARDA\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model,x,y)
# Out:
# Accuracy: 61.25000000000001
# CV Score: 47.96630094043888

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
classify(model,x,y)
# Out:
# Accuracy: 70.5
# CV Score: 56.974921630094045

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
classify(model,x,y)
# Out:
# Accuracy: 70.25
# CV Score: 56.537421630094045

# %%
#Model Saving

# %%
import pickle
filename="Wine_Quality"
pickle.dump(model,open(filename,"wb"))
